# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandroSC2512/edd_1358_2021/blob/master/2octubre1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tipo de dato

# %%
#Stirng puede emplear 
universidad="    Universidad     Nacional     Autonoma de Mexico"
print(universidad)
#Cuando el string es una sola palabra se usa '' ->Buena practica
carrera = 'ico'
area = "softeare"
division = "Division de las ciencas fisico y matematico"
print(carrera,area)
print(division)
# Triple comilla cuando el string incluye varios renglones
frase='''
Si funviona !!No 
lo 
arregles'''

help(str)

print(universidad.upper())
# Out:
#     Univerdiad     Nacional     Autonoma de Mexico
# ico softeare
# Division de las ciencas fisico y matematico
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
# ...

# %%
print(universidad)
print(universidad.title())
#Eliminar los espacios de derecha a izquierda \n
universidad=universidad.strip()
print(universidad)
lista=universidad.split(" ")
print(lista)
nueva=(" ")
for l in lista:
  if len(1) > 0:
    nueva+=1+" "
print(nueva)
  
numero="1,2,34,56,100"
separados=numero.split(",")
print(separados)
numero_int = []
for numero in separados:
  numeros_int.append(int(numero))

print(numero_int)

print(nueva)
print(nueva.index("na"))
print(nueva.replace(" ","-"))
print(nueva)
# Out:
# Univerdiad     Nacional     Autonoma de Mexico
# Univerdiad     Nacional     Autonoma De Mexico
# Univerdiad     Nacional     Autonoma de Mexico
# ['Univerdiad', '', '', '', '', 'Nacional', '', '', '', '', 'Autonoma', 'de', 'Mexico']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ffd8c2ad73aa> in <module>()
#       8 nueva=(" ")
#       9 for l in lista:
# ---> 10   if len(1) > 0:
#      11     nueva+=1+" "
#      12 print(nueva)
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #Slicing
# sintaxis
# [inicio : stop : incremento]

# %%
#Selector de elementos dentro de un str
print(nueva[0] )
nueva=nueva.strip()
print(nueva [ len(nueva)-1]) #indexado negativo
print(nueva[-2])

#Slicing
print(nueva)
print(nueva[12 : 20 : 1])
print(nueva[-6 : : 1])
#mexico alrevez
print(nueva[1 : -7 : -1])
#Valores por defecto [0:long de la lista:1]
print(nueva[::2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-2ff093c1ec16> in <module>()
#       1 #Selector de elementos dentro de un str
# ----> 2 print(nueva[0] )
#       3 nueva=nueva.strip()
#       4 print(nueva [ len(nueva)-1]) #indexado negativo
#       5 print(nueva[-2])
#
# IndexError: string index out of range

# %% [markdown]
# Tipo de dato bool
# Acepta solo dos valores
# True bool(1)
# False bool(0)

# %%
print(bool(0))
print(bool(1))
flag=12
print(bool(flag))
# Out:
# False
# True
# True

# %%
#Comentarios
Para un comentaro de una linea #
Pra un comentaro de multiple linea equivalente a

# %% [markdown]
# #Comentarios
# Para un comentaro de una linea #
# Pra un comentaro de multiple linea equivalente a /**/ de java o leng C se utiliza

# %%
#Este es un comentario de una linea
"*"
Este 
es un
comentario de 
multiple 
linea 
"*"

# %% [markdown]
# Funcion Print
# Hay 4 foras de usar print
# 1.- con comas
# 2.- con signo
# 3.- con la funcion format() de la clase string
# 4.- con el operador f""

# %%
#Con comas
cantidad = 2
precio_chetos = 2
precio_fanta = 12
print(cantidad,precio_chetos,precio_fanta)

#Con signo solo opera con str
print("Hola"+"Mundo")
print(cantidad,precio_chetos,precio_fanta)
print(str(cantidad)+str(precio_chetos)+str(precio_fanta))
# Out:
# 2 2 12
# HolaMundo
# 2 2 12
# 2212
